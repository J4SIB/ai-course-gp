# %% [markdown]
# <a href="https://colab.research.google.com/github/J4SIB/ai-course-gp/blob/main/lesson9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {'A': 25, 'B': 30, 'C': 40}
s = pd.Series(data)
print(s)
# Out:
# A    25
# B    30
# C    40
# dtype: int64

# %%
import numpy as np

s2 = pd.Series([10,20,22,40, np.nan], index=['A', 'B', 'C', 'D', 'E'])
print(s2)

print(s.size)
print(s.shape)
print(s.dtype)
print(s.index)
print(s.values)
print(s['B'])
print(s.iloc[1])
# Out:
# A    10.0
# B    20.0
# C    22.0
# D    40.0
# E     NaN
# dtype: float64
# 3
# (3,)
# int64
# Index(['A', 'B', 'C'], dtype='object')
# [25 30 40]
# 30
# 30

# %%
data = {
  "cena" : [15, 20, 17],
  "ilość": [50, 40, 45]
  }

df = pd.DataFrame(data, index = ["produkt A", "produkt B", "produkt C"])

df
# Out:
#            cena  ilość
# produkt A    15     50
# produkt B    20     40
# produkt C    17     45

# %%
print(df.loc["produkt A"])
# Out:
# cena     15
# ilość    50
# Name: produkt A, dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, produkt A to produkt C
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cena    3 non-null      int64
#  1   ilość   3 non-null      int64
# dtypes: int64(2)
# memory usage: 180.0+ bytes
# None

# %%
import pandas as pd

df = pd.read_excel("Gigathon_Wyniki.xlsx")
df
# Out:
#          Imię  Wiek  Punktacja
# 0      Łukasz    18       51.0
# 1   Magdalena    18       52.0
# 2    Radosław    15       46.0
# 3      Patryk    15       52.0
# 4        Anna    14      110.0
# 5     Dagmara    16        NaN
# 6      Tomasz    16      112.0
# 7    Weronika    17      104.0
# 8     Nikodem    17       97.0
# 9      Bartek    14        NaN
# 10      Jakub    16       61.0
# 11   Gabriela    16       92.0
# 12     Hubert    15      120.0
# 13    Zuzanna    13       70.0
# 14     Oliwia    14       84.0
# 15      Filip    16      100.0
# 16    Ewelina    17       98.0
# 17   Karolina    14       63.0
# 18     Xawery    17       39.0
# 19     Cezary    13        NaN
# 20        Iga    15       77.0
# 21    Urszula    14      102.0
# 22        Jan    17      102.0
# 23     Michał    15        NaN
# 24  Katarzyna    18       68.0

# %%
print(df.head(3))
print(df.tail(3))
# Out:
#         Imię  Wiek  Punktacja
# 0     Łukasz    18       51.0
# 1  Magdalena    18       52.0
# 2   Radosław    15       46.0
#          Imię  Wiek  Punktacja
# 22        Jan    17      102.0
# 23     Michał    15        NaN
# 24  Katarzyna    18       68.0

# %%
df['Wynik Procentowy'] = df['Punktacja'] / 120 * 100
df
# Out:
#          Imię  Wiek  Punktacja  Wynik Procentowy
# 0      Łukasz    18       51.0         42.500000
# 1   Magdalena    18       52.0         43.333333
# 2    Radosław    15       46.0         38.333333
# 3      Patryk    15       52.0         43.333333
# 4        Anna    14      110.0         91.666667
# 5     Dagmara    16        NaN               NaN
# 6      Tomasz    16      112.0         93.333333
# 7    Weronika    17      104.0         86.666667
# 8     Nikodem    17       97.0         80.833333
# 9      Bartek    14        NaN               NaN
# 10      Jakub    16       61.0         50.833333
# 11   Gabriela    16       92.0         76.666667
# 12     Hubert    15      120.0        100.000000
# 13    Zuzanna    13       70.0         58.333333
# 14     Oliwia    14       84.0         70.000000
# 15      Filip    16      100.0         83.333333
# 16    Ewelina    17       98.0         81.666667
# 17   Karolina    14       63.0         52.500000
# 18     Xawery    17       39.0         32.500000
# 19     Cezary    13        NaN               NaN
# 20        Iga    15       77.0         64.166667
# 21    Urszula    14      102.0         85.000000
# 22        Jan    17      102.0         85.000000
# 23     Michał    15        NaN               NaN
# 24  Katarzyna    18       68.0         56.666667

# %%
df.dropna(inplace = True)
df
# Out:
#          Imię  Wiek  Punktacja  Wynik Procentowy
# 0      Łukasz    18       51.0         42.500000
# 1   Magdalena    18       52.0         43.333333
# 2    Radosław    15       46.0         38.333333
# 3      Patryk    15       52.0         43.333333
# 4        Anna    14      110.0         91.666667
# 6      Tomasz    16      112.0         93.333333
# 7    Weronika    17      104.0         86.666667
# 8     Nikodem    17       97.0         80.833333
# 10      Jakub    16       61.0         50.833333
# 11   Gabriela    16       92.0         76.666667
# 12     Hubert    15      120.0        100.000000
# 13    Zuzanna    13       70.0         58.333333
# 14     Oliwia    14       84.0         70.000000
# 15      Filip    16      100.0         83.333333
# 16    Ewelina    17       98.0         81.666667
# 17   Karolina    14       63.0         52.500000
# 18     Xawery    17       39.0         32.500000
# 20        Iga    15       77.0         64.166667
# 21    Urszula    14      102.0         85.000000
# 22        Jan    17      102.0         85.000000
# 24  Katarzyna    18       68.0         56.666667

# %%
df.sort_values(by="Punktacja", ascending = False, inplace = True)
df
# Out:
#          Imię  Wiek  Punktacja  Wynik Procentowy
# 12     Hubert    15      120.0        100.000000
# 6      Tomasz    16      112.0         93.333333
# 4        Anna    14      110.0         91.666667
# 7    Weronika    17      104.0         86.666667
# 22        Jan    17      102.0         85.000000
# 21    Urszula    14      102.0         85.000000
# 15      Filip    16      100.0         83.333333
# 16    Ewelina    17       98.0         81.666667
# 8     Nikodem    17       97.0         80.833333
# 11   Gabriela    16       92.0         76.666667
# 14     Oliwia    14       84.0         70.000000
# 20        Iga    15       77.0         64.166667
# 13    Zuzanna    13       70.0         58.333333
# 24  Katarzyna    18       68.0         56.666667
# 17   Karolina    14       63.0         52.500000
# 10      Jakub    16       61.0         50.833333
# 3      Patryk    15       52.0         43.333333
# 1   Magdalena    18       52.0         43.333333
# 0      Łukasz    18       51.0         42.500000
# 2    Radosław    15       46.0         38.333333
# 18     Xawery    17       39.0         32.500000

# %%
df['Zakwalifikowany'] = df['Wynik Procentowy'] >= 70
df
# Out:
#          Imię  Wiek  Punktacja  Wynik Procentowy  Zakwalifikowany
# 12     Hubert    15      120.0        100.000000             True
# 6      Tomasz    16      112.0         93.333333             True
# 4        Anna    14      110.0         91.666667             True
# 7    Weronika    17      104.0         86.666667             True
# 22        Jan    17      102.0         85.000000             True
# 21    Urszula    14      102.0         85.000000             True
# 15      Filip    16      100.0         83.333333             True
# 16    Ewelina    17       98.0         81.666667             True
# 8     Nikodem    17       97.0         80.833333             True
# 11   Gabriela    16       92.0         76.666667             True
# 14     Oliwia    14       84.0         70.000000             True
# 20        Iga    15       77.0         64.166667            False
# 13    Zuzanna    13       70.0         58.333333            False
# 24  Katarzyna    18       68.0         56.666667            False
# 17   Karolina    14       63.0         52.500000            False
# 10      Jakub    16       61.0         50.833333            False
# 3      Patryk    15       52.0         43.333333            False
# 1   Magdalena    18       52.0         43.333333            False
# 0      Łukasz    18       51.0         42.500000            False
# 2    Radosław    15       46.0         38.333333            False
# 18     Xawery    17       39.0         32.500000            False

# %%
df.groupby(["Zakwalifikowany", "Wiek"])[["Punktacja", "Wynik Procentowy"]].agg(['count', 'min', 'mean', 'median'])
# Out:
#                      Punktacja                           Wynik Procentowy  \
#                          count    min        mean median            count
# Zakwalifikowany Wiek
# False           13           1   70.0   70.000000   70.0                1
#                 14           1   63.0   63.000000   63.0                1
#                 15           3   46.0   58.333333   52.0                3
#                 16           1   61.0   61.000000   61.0                1
#                 17           1   39.0   39.000000   39.0                1
#                 18           3   51.0   57.000000   52.0                3
# True            14           3   84.0   98.666667  102.0                3
#                 15           1  120.0  120.000000  120.0                1
#                 16           3   92.0  101.333333  100.0                3
#                 17           4   97.0  100.250000  100.0                4
#
#
#                              min        mean      median
# Zakwalifikowany Wiek
# False           13     58.333333   58.333333   58.333333
#                 14     52.500000   52.500000   52.500000
#                 15     38.333333   48.611111   43.333333
#                 16     50.833333   50.833333   50.833333
#                 17     32.500000   32.500000   32.500000
#                 18     42.500000   47.500000   43.333333
# True            14     70.000000   82.222222   85.000000
#                 15    100.000000  100.000000  100.000000
#                 16     76.666667   84.444444   83.333333
#                 17     80.833333   83.541667   83.333333

# %%
df_zakwalifikowani = df[df['Zakwalifikowany']]
df_niezakwalifikowani = df[~df['Zakwalifikowany']]

#mini upgrade
df_zakwalifikowani.drop('Zakwalifikowany',axis=1,inplace=True)
df_niezakwalifikowani.drop('Zakwalifikowany',axis=1,inplace=True)

df_zakwalifikowani.to_excel("zakwalifikowani.xlsx")
df_niezakwalifikowani.to_excel("niezakwalifikowani.xlsx")
